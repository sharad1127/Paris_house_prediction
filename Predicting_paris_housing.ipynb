# %% [markdown]
# ## Importing required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading dataset

# %%
data= pd.read_csv('/Users/musubimanagement/Desktop/kaggle_project/Paris-house-prediction/ParisHousingClass.csv')
data.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price category
# ...

# %%
data.shape
# Out:
# (10000, 18)

# %%
data.describe()
# Out:
#        squareMeters  numberOfRooms       hasYard       hasPool        floors  \
# count   10000.00000   10000.000000  10000.000000  10000.000000  10000.000000
# mean    49870.13120      50.358400      0.508700      0.496800     50.276300
# std     28774.37535      28.816696      0.499949      0.500015     28.889171
# min        89.00000       1.000000      0.000000      0.000000      1.000000
# 25%     25098.50000      25.000000      0.000000      0.000000     25.000000
# 50%     50105.50000      50.000000      1.000000      0.000000     50.000000
# 75%     74609.75000      75.000000      1.000000      1.000000     76.000000
# max     99999.00000     100.000000      1.000000      1.000000    100.000000
#
#            cityCode  cityPartRange  numPrevOwners         made    isNewBuilt  \
# count  10000.000000   10000.000000   10000.000000  10000.00000  10000.000000
# mean   50225.486100       5.510100       5.521700   2005.48850      0.499100
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %% [markdown]
# ## Checking For Missing Values

# %%
miss_val=data.isna().sum()
miss_val
# Out:
# squareMeters         0
# numberOfRooms        0
# hasYard              0
# hasPool              0
# floors               0
# cityCode             0
# cityPartRange        0
# numPrevOwners        0
# made                 0
# isNewBuilt           0
# hasStormProtector    0
# basement             0
# attic                0
# garage               0
# hasStorageRoom       0
# hasGuestRoom         0
# price                0
# category             0
# dtype: int64

# %%
corr_data=data.corr()
corr_data
# Out:
#                    squareMeters  numberOfRooms   hasYard   hasPool    floors  \
# squareMeters           1.000000       0.009573 -0.006650 -0.005594  0.001109
# numberOfRooms          0.009573       1.000000 -0.011240  0.017015  0.022244
# hasYard               -0.006650      -0.011240  1.000000  0.015514 -0.000883
# hasPool               -0.005594       0.017015  0.015514  1.000000 -0.004006
# floors                 0.001109       0.022244 -0.000883 -0.004006  1.000000
# cityCode              -0.001541       0.009040  0.006760  0.008072  0.002207
# cityPartRange          0.008758       0.008340  0.005023  0.014613 -0.004921
# numPrevOwners          0.016619       0.016766  0.004279 -0.006848  0.002463
# made                  -0.007207       0.003978  0.002214  0.001894  0.005022
# isNewBuilt            -0.010667      -0.002865 -0.008370  0.000188  0.002458
# hasStormProtector      0.007480      -0.001656 -0.007598 -0.001001 -0.008566
# ...

# %% [markdown]
# # Label Encoding

# %%
data['category'].value_counts()
# Out:
# Basic     8735
# Luxury    1265
# Name: category, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

def label_encoded(feat):
    le=LabelEncoder()
    le.fit(feat)
    print(feat.name,le.classes_)
    return le.transform(feat)
data['category']=label_encoded(data['category'])
# Out:
# category ['Basic' 'Luxury']

# %% [markdown]
# ## Plotting Correlation

# %%
plt.rcParams["figure.figsize"] = (18,14)
sns.heatmap(corr_data,annot=True, cmap="cubehelix_r",linewidth=0.5,square='True')
plt.show()

# %%
data.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price  category
# ...

# %% [markdown]
# # Linear Regression Algorithm

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.metrics import accuracy_score

# %%
reporting={}
X=data.drop(['category'],axis =1)
y=data['category']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.27)

# %%
regr = linear_model.LinearRegression()
fitregr=regr.fit(X_train, y_train)
predregrtrain=fitregr.predict(X_train)
predregrtest=fitregr.predict(X_test)

# %%
print('Linear model intercept: {} and the coefficients are: {}'
     .format(fitregr.intercept_,fitregr.coef_))
# Out:
# Linear model intercept: -0.4929030813875618 and the coefficients are: [-1.61773732e-04 -1.87823883e-05  2.44404548e-01  2.48282481e-01
#  -1.03521900e-04 -1.89584801e-08 -1.98341186e-03  3.58127610e-04
#   1.28138924e-04  2.53903489e-01  3.07349525e-04  3.65265687e-08
#  -9.24744090e-07  2.30262453e-06 -3.85676758e-04 -2.07174438e-04
#   1.61694839e-06]

# %%
train_set_r2 = r2_score(y_train, predregrtrain)
print('Linear model, R2 train score is : {}'.format(train_set_r2))
test_set_r2 = r2_score(y_test, predregrtest)
print('Linear model, R2 test score is : {}'.format(test_set_r2))
# Out:
# Linear model, R2 train score is : 0.430195711452769
# Linear model, R2 test score is : 0.42846053421748886

# %% [markdown]
# # Random Forest Algorithm

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid = {'n_estimators': [1, 30,100], 'max_features': ['auto', 'log2'], 'max_depth': [4,6, 8,10]}
clf_rf = RandomForestClassifier(random_state=5)

cv_model=GridSearchCV(estimator=clf_rf,param_grid=param_grid,cv=10,scoring='recall',n_jobs=-1)
cv_model.fit(X_train,y_train)
cv_model.best_params_
# Out:
# {'max_depth': 6, 'max_features': 'auto', 'n_estimators': 30}

# %%
best_model= RandomForestClassifier(max_depth=6,max_features='auto',n_estimators=30)
best_model.fit(X_train,y_train)
pred=best_model.predict(X_test)
print("-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
print(f'The Accuracy Score is {round(accuracy_score(pred,y_test)*100,4)}%')
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# The Accuracy Score is 99.963%

# %%
import pickle 
Pkl_Filename = "Lr_pickle.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(best_model, file)

# %%
with open(Pkl_Filename, 'rb') as file:  
    Pickled_LR_Model = pickle.load(file)
